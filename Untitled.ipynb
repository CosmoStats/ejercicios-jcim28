# %%
from getdist import plots, MCSamples
import numpy as np

# cargar cadenas
!
s1 = np.loadtxt('post_equal_weights.dat')

# %%
s1
# Out:
# array([[ 1.23940779e-01,  2.40579956e+00, -1.93189049e+01, ...,
#          2.48516816e-01, -6.97350183e-01, -2.00009091e+03],
#        [ 1.41698162e-01,  2.33633977e+00, -1.93158821e+01, ...,
#          1.36751692e-01, -6.32846865e-01, -2.00005721e+03],
#        [ 1.29936653e-01,  2.44370664e+00, -1.93072487e+01, ...,
#          3.70190764e-02, -5.17550054e-01, -1.99965571e+03],
#        ...,
#        [ 1.34400491e-01,  2.45935690e+00, -1.93156154e+01, ...,
#          1.49870962e-01, -5.98879062e-01, -1.98918337e+03],
#        [ 1.33184827e-01,  2.48254753e+00, -1.93190855e+01, ...,
#          1.55216465e-01, -6.31271663e-01, -1.98959102e+03],
#        [ 1.33403591e-01,  2.42892600e+00, -1.93157385e+01, ...,
#          9.54381868e-02, -5.72987067e-01, -1.98943891e+03]])
