# %%
from getdist import plots, MCSamples
import numpy as np

# cargar cadenas
s1 = np.loadtxt('Omega_L/post_equal_weights.dat')
"""s2 = np.loadtxt('model2_post_equal_weights.dat')

# columnas de parámetros
samples1 = s1[:, :-1]
samples2 = s2[:, :-1]

names = ['omega_m', 'H0', 'sigma8']
labels = [r'\Omega_m', r'H_0', r'\sigma_8']

g1 = MCSamples(samples=samples1,
               names=names,
               labels=labels,
               label='Modelo 1')

g2 = MCSamples(samples=samples2,
               names=names,
               labels=labels,
               label='Modelo 2')

g = plots.get_subplot_plotter()
g.triangle_plot([g1, g2],
                filled=True)"""
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 import numpy as np
#       4 # cargar cadenas
# ----> 5 s1 = np.loadtxt('Omega_L/post_equal_weights.dat')
#       6 """s2 = np.loadtxt('model2_post_equal_weights.dat')
#       7
#       8 # columnas de parámetros
#    (...)
#      26 g.triangle_plot([g1, g2],
#      27                 filled=True)"""
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/npyio.py:1338, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1335 if isinstance(delimiter, bytes):
#    1336     delimiter = delimiter.decode('latin1')
# -> 1338 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1339             converters=converters, skiplines=skiprows, usecols=usecols,
# ...
