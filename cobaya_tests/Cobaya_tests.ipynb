# %%
from getdist import loadMCSamples

samples = loadMCSamples("./test_bao")
# Out:
# WARNING:root:outlier fraction 0.0029411764705882353
# ./test_bao.1.txt
# Removed no burn in

# %%
print(samples.getParamNames().names)
# Out:
# [<getdist.paramnames.ParamInfo object at 0x10c2f89e0>, <getdist.paramnames.ParamInfo object at 0x10c2f8c80>, <getdist.paramnames.ParamInfo object at 0x10c2f95b0>, <getdist.paramnames.ParamInfo object at 0x10c2f82f0>, <getdist.paramnames.ParamInfo object at 0x10c2f9790>, <getdist.paramnames.ParamInfo object at 0x10c2f9640>]

# %%
from getdist import plots

g = plots.get_subplot_plotter()

g.triangle_plot(
    [samples],
    ['omega_cdm','H0'],
    filled=True
)
# Out:
# WARNING:root:2D kernel density bandwidth optimizer failed for omega_cdm, H0. Using fallback width: f(a) and f(b) must have different signs

# %%
print(samples.getMargeStats())
# Out:
# Marginalized limits: 0.68; 0.95; 0.99
#
# parameter                  mean           sddev          lower1         upper1         limit1 lower2         upper2         limit2 lower3         upper3         limit3
# omega_cdm                  1.7587443E-01  7.1035766E-02  5.0000000E-02  3.0000000E-01  none   5.0000000E-02  3.0000000E-01  none   5.0000000E-02  3.0000000E-01  none    omega_cdm
# H0                         7.1570481E+01  7.4073910E+00  6.3968962E+01  7.9818821E+01  two    5.8154477E+01  8.4840827E+01  two    5.5424812E+01  8.7872987E+01  two     H0
# chi2__BAO*                 1.8902543E+00  1.6308583E+00  5.9284465E-01  1.9259934E+00  two    4.8256655E-01  5.8864016E+00  two    4.2889193E-01  8.6892790E+00  two     \chi^2_\mathrm{BAO}
# chi2*                      1.8902543E+00  1.6308583E+00  5.9284465E-01  1.9259934E+00  two    4.8256655E-01  5.8864016E+00  two    4.2889193E-01  8.6892790E+00  two     \chi^2
# ...

# %%
print(samples.getMeans())
# Out:
# [ 0.17587443 71.57048063  1.89025428  1.89025428  0.86454425  1.02571003]

# %%
print(samples.numrows)
# Out:
# 2720

# %%
samples = loadMCSamples("./test_sfdm")
# Out:
# WARNING:root:outlier fraction 0.12083333333333333
# ./test_sfdm.1.txt
# Removed no burn in

# %%
g = plots.get_subplot_plotter()

g.triangle_plot(
    [samples],
    ['omega_cdm','H0'],
    filled=True
)

# %%
samples = loadMCSamples("./test_sfdm1")
# Out:
# WARNING:root:outlier fraction 0.12352941176470589
# ./test_sfdm1.1.txt
# Removed no burn in

# %%
print(samples.getMargeStats())
# Out:
# Marginalized limits: 0.68; 0.95; 0.99
#
# parameter                mean           sddev          lower1         upper1         limit1 lower2         upper2         limit2 lower3         upper3         limit3
# Omega_sfdm_1             1.7991193E-01  1.5596952E-02  1.7369750E-01  2.0000000E-01  <      1.4967738E-01  2.0000000E-01  <      1.4241824E-01  2.0000000E-01  <       Omega_sfdm_1
# chi2__BAO*               5.8675067E+00  9.6343407E-01  4.6240384E+00  6.4582025E+00  two    4.4805638E+00  7.7832897E+00  two    4.3456765E+00  8.1327688E+00  two     \chi^2_\mathrm{BAO}
# chi2*                    5.8675067E+00  9.6343407E-01  4.6240384E+00  6.4582025E+00  two    4.4805638E+00  7.7832897E+00  two    4.3456765E+00  8.1327688E+00  two     \chi^2
# chi2__bao.sdss_dr7_mgs*  5.8675067E+00  9.6343407E-01  4.6240384E+00  6.4582025E+00  two    4.4805638E+00  7.7832897E+00  two    4.3456765E+00  8.1327688E+00  two     \chi^2_\mathrm{bao.sdss\ dr7\ mgs}

# %%
g.triangle_plot(
    [samples],
    ['Omega_sfdm_1'],
    filled=True
)

# %%
samples = loadMCSamples("./test_omega")
# Out:
# WARNING:root:outlier fraction 0.1013157894736842
# ./test_omega.1.txt
# Removed no burn in

# %%
g.triangle_plot(
    [samples],
    ['Omega_sfdm_1'],
    filled=True
)

# %%
samples = loadMCSamples("./test_mass")
# Out:
# WARNING:root:outlier fraction 0.08636363636363636
# ./test_mass.1.txt
# Removed no burn in

# %%
print(samples.getMargeStats())
# Out:
# WARNING:root:auto bandwidth for m_sfdm1 very small or failed (h=0.0006471958639453473,N_eff=227.1880562406438). Using fallback (h=0.12334030320845496)
# Marginalized limits: 0.68; 0.95; 0.99
#
# parameter                mean           sddev          lower1         upper1         limit1 lower2         upper2         limit2 lower3         upper3         limit3
# m_sfdm1                 -2.0938314E+01  1.1015560E+00 -2.2221474E+01 -1.9672733E+01  two   -2.3000000E+01 -1.9000000E+01  none  -2.3000000E+01 -1.9000000E+01  none    m_sfdm1
# chi2__BAO*               1.9692981E-02  1.5698155E-06  1.9691856E-02  1.9693809E-02  two    1.9690119E-02  1.9696868E-02  two    1.9687353E-02  1.9697182E-02  two     \chi^2_\mathrm{BAO}
# chi2*                    1.9692981E-02  1.5698155E-06  1.9691856E-02  1.9693809E-02  two    1.9690119E-02  1.9696868E-02  two    1.9687353E-02  1.9697182E-02  two     \chi^2
# ...

# %%
g.triangle_plot(
    [samples],
    ['m_sfdm1'],
    filled=True
)
# Out:
# WARNING:root:auto bandwidth for m_sfdm1 very small or failed (h=0.0006471958639453473,N_eff=227.1880562406438). Using fallback (h=0.12334030320845496)

# %%
samples = loadMCSamples("./test_multi")
print(samples.getMargeStats())
# Out:
# WARNING:root:auto bandwidth for omega_cdm very small or failed (h=0.0005230258777567013,N_eff=2046.7353746554309). Using fallback (h=0.08383500199140022)
# WARNING:root:auto bandwidth for chi2 very small or failed (h=0.0004666621722972578,N_eff=3173.0942106125426). Using fallback (h=0.0060588823493957725)
# ./test_multi.1.txt
# Removed no burn in
# Marginalized limits: 0.68; 0.95; 0.99
#
# parameter                mean           sddev          lower1         upper1         limit1 lower2         upper2         limit2 lower3         upper3         limit3
# Omega_sfdm_1             2.5149621E-01  2.8600480E-02  2.0000000E-01  3.0000000E-01  none   2.0000000E-01  3.0000000E-01  none   2.0000000E-01  3.0000000E-01  none    Omega_sfdm_1
# m_sfdm1                 -2.1067088E+01  1.1458067E+00 -2.3000000E+01 -1.9000000E+01  none  -2.3000000E+01 -1.9000000E+01  none  -2.3000000E+01 -1.9000000E+01  none    m_sfdm1
# ...

# %%
g.triangle_plot(
    [samples],
    ['Omega_sfdm_1', 'm_sfdm1','omega_b', 'omega_cdm', 'H0'],
    filled=True
)
# Out:
# WARNING:root:auto bandwidth for omega_cdm very small or failed (h=0.0005230258777567013,N_eff=2046.7353746554309). Using fallback (h=0.08383500199140022)

# %%
samples = loadMCSamples("./test_multi_bao")
print(samples.getMargeStats())
# Out:
# WARNING:root:auto bandwidth for Omega_sfdm_1 very small or failed (h=0.0005152413466132391,N_eff=2823.3167055628714). Using fallback (h=0.08153879049988895)
# WARNING:root:auto bandwidth for m_sfdm1 very small or failed (h=0.0005501363566247183,N_eff=3062.610092223441). Using fallback (h=0.08032919276517542)
# WARNING:root:auto bandwidth for chi2 very small or failed (h=0.0016239532469443508,N_eff=3997.32837106965). Using fallback (h=0.0057258535770143585)
# ./test_multi_bao.1.txt
# Removed no burn in
# Marginalized limits: 0.68; 0.95; 0.99
#
# parameter                  mean           sddev          lower1         upper1         limit1 lower2         upper2         limit2 lower3         upper3         limit3
# Omega_sfdm_1               2.5003459E-01  2.8858684E-02  2.0000000E-01  3.0000000E-01  none   2.0000000E-01  3.0000000E-01  none   2.0000000E-01  3.0000000E-01  none    Omega_sfdm_1
# ...

# %%
g.triangle_plot(
    [samples],
    ['Omega_sfdm_1', 'm_sfdm1','omega_b', 'omega_cdm', 'H0'],
    filled=True
)
# Out:
# WARNING:root:auto bandwidth for Omega_sfdm_1 very small or failed (h=0.0005152413466132391,N_eff=2823.3167055628714). Using fallback (h=0.08153879049988895)
# WARNING:root:auto bandwidth for m_sfdm1 very small or failed (h=0.0005501363566247183,N_eff=3062.610092223441). Using fallback (h=0.08032919276517542)

# %%
samples = loadMCSamples("./test_multi_sn")
print(samples.getMargeStats())
# Out:
# WARNING:root:auto bandwidth for chi2 very small or failed (h=0.00030327969268077515,N_eff=4215.250030389864). Using fallback (h=0.003593249595752104)
# ./test_multi_sn.1.txt
# Removed no burn in
# Marginalized limits: 0.68; 0.95; 0.99
#
# parameter           mean           sddev          lower1         upper1         limit1 lower2         upper2         limit2 lower3         upper3         limit3
# Omega_sfdm_1        2.3235837E-01  2.1244628E-02  2.0000000E-01  2.4102276E-01  >      2.0000000E-01  2.7202663E-01  >      2.0000000E-01  2.8750802E-01  >       Omega_sfdm_1
# m_sfdm1            -2.0936037E+01  1.1395534E+00 -2.3000000E+01 -1.9000000E+01  none  -2.3000000E+01 -1.9000000E+01  none  -2.3000000E+01 -1.9000000E+01  none    m_sfdm1
# omega_b             2.1807599E-02  2.2964184E-03  1.8000000E-02  2.6000000E-02  none   1.8000000E-02  2.6000000E-02  none   1.8000000E-02  2.6000000E-02  none    omega_b
# ...

# %%
g.triangle_plot(
    [samples],
    ['Omega_sfdm_1', 'm_sfdm1','omega_b', 'omega_cdm', 'H0'],
    filled=True
)
